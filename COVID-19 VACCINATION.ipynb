# %%
import pandas as pd

# %%
df= pd.read_csv("https://github.com/owid/covid-19-data/raw/master/public/data/vaccinations/vaccinations.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15019 entries, 0 to 15018
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             15019 non-null  object
#  1   iso_code                             15019 non-null  object
#  2   date                                 15019 non-null  object
#  3   total_vaccinations                   9300 non-null   float64
#  4   people_vaccinated                    8579 non-null   float64
#  5   people_fully_vaccinated              6405 non-null   float64
#  6   daily_vaccinations_raw               7904 non-null   float64
#  7   daily_vaccinations                   14798 non-null  float64
#  8   total_vaccinations_per_hundred       9300 non-null   float64
#  9   people_vaccinated_per_hundred        8579 non-null   float64
#  10  people_fully_vaccinated_per_hundred  6405 non-null   float64
#  11  daily_vaccinations_per_million       14798 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 1.4+ MB

# %%
df.head(10)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
# 5                      NaN                     NaN              1367.0
# 6                      NaN                     NaN              1367.0
# 7                      NaN                     NaN              1580.0
# 8                      NaN                     NaN              1794.0
# 9                      NaN                     NaN              2008.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                            0.02                           0.02
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
# 5                                  NaN                            35.0
# 6                                  NaN                            35.0
# 7                                  NaN                            41.0
# 8                                  NaN                            46.0
# 9                                  NaN                            52.0
